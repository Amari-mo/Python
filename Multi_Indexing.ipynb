# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#         Date   Country Product  Sales     Category Region
# 0 2023-01-01       DRC       A  446.0         Food  North
# 1 2023-01-02  Tanzania       C   56.0  Electronics  South
# 2 2023-01-03    Uganda       C   65.0     Clothing  South
# 3 2023-01-04     Kenya       B  364.0     Clothing   West
# 4 2023-01-05     Kenya       C  260.0  Electronics   West

# %%
new_df = df.set_index(['Country'])

# %%
new_df.head()
# Out:
#                Date Product  Sales     Category Region
# Country
# DRC      2023-01-01       A  446.0         Food  North
# Tanzania 2023-01-02       C   56.0  Electronics  South
# Uganda   2023-01-03       C   65.0     Clothing  South
# Kenya    2023-01-04       B  364.0     Clothing   West
# Kenya    2023-01-05       C  260.0  Electronics   West

# %%
new_df = df.set_index(["Country", "Product"])

# %%
new_df.head()
# Out:
#                        Date  Sales     Category Region
# Country  Product
# DRC      A       2023-01-01  446.0         Food  North
# Tanzania C       2023-01-02   56.0  Electronics  South
# Uganda   C       2023-01-03   65.0     Clothing  South
# Kenya    B       2023-01-04  364.0     Clothing   West
#          C       2023-01-05  260.0  Electronics   West

# %%
new_df.index
# Out:
# MultiIndex([(     'DRC', 'A'),
#             ('Tanzania', 'C'),
#             (  'Uganda', 'C'),
#             (   'Kenya', 'B'),
#             (   'Kenya', 'C'),
#             (     'DRC', 'A'),
#             (   'Kenya', 'C'),
#             (   'Kenya', 'C'),
#             (   'Kenya', 'A'),
#             (  'Uganda', 'C'),
#             (     'DRC', 'A'),
#             (   'Kenya', 'B'),
#             ('Tanzania', 'A'),
#             (     'DRC', 'C'),
#             (   'Kenya', 'A'),
#             (   'Kenya', 'A'),
#             (   'Kenya', 'C'),
#             (  'Uganda', 'A'),
#             (  'Uganda', 'B'),
#             (   'Kenya', 'B'),
#             ('Tanzania', 'B'),
#             ('Tanzania', 'C'),
#             ('Tanzania', 'B'),
#             (   'Kenya', 'A'),
#             (   'Kenya', 'C'),
#             (  'Uganda', 'C'),
#             (     'DRC', 'C'),
#             ('Tanzania', 'C'),
#             (  'Uganda', 'A'),
#             ('Tanzania', 'B'),
# ...

# %%
merged_index = new_df.index.map(lambda x: f'{x[0]}_{x[1]}')
merged_index
# Out:
# Index(['DRC_A', 'Tanzania_C', 'Uganda_C', 'Kenya_B', 'Kenya_C', 'DRC_A',
#        'Kenya_C', 'Kenya_C', 'Kenya_A', 'Uganda_C', 'DRC_A', 'Kenya_B',
#        'Tanzania_A', 'DRC_C', 'Kenya_A', 'Kenya_A', 'Kenya_C', 'Uganda_A',
#        'Uganda_B', 'Kenya_B', 'Tanzania_B', 'Tanzania_C', 'Tanzania_B',
#        'Kenya_A', 'Kenya_C', 'Uganda_C', 'DRC_C', 'Tanzania_C', 'Uganda_A',
#        'Tanzania_B', 'Tanzania_B', 'Tanzania_C', 'DRC_C', 'DRC_B', 'Kenya_A',
#        'DRC_B', 'Kenya_C', 'Kenya_C', 'DRC_A', 'Kenya_C', 'Tanzania_B',
#        'Tanzania_B', 'Tanzania_B', 'Tanzania_B', 'DRC_A', 'Kenya_B', 'Kenya_A',
#        'Tanzania_A', 'DRC_A', 'Tanzania_A'],
#       dtype='object')

# %%
new_df.head()
# Out:
#                        Date  Sales     Category Region
# Country  Product
# DRC      A       2023-01-01  446.0         Food  North
# Tanzania C       2023-01-02   56.0  Electronics  South
# Uganda   C       2023-01-03   65.0     Clothing  South
# Kenya    B       2023-01-04  364.0     Clothing   West
#          C       2023-01-05  260.0  Electronics   West

# %%
new_df.index = merged_index
new_df
# Out:
#                  Date  Sales     Category Region
# DRC_A      2023-01-01  446.0         Food  North
# Tanzania_C 2023-01-02   56.0  Electronics  South
# Uganda_C   2023-01-03   65.0     Clothing  South
# Kenya_B    2023-01-04  364.0     Clothing   West
# Kenya_C    2023-01-05  260.0  Electronics   West
# DRC_A      2023-01-06    NaN  Electronics  South
# Kenya_C    2023-01-07    NaN  Electronics   West
# Kenya_C    2023-01-08    NaN         Food   East
# Kenya_A    2023-01-09    NaN  Electronics  North
# Uganda_C   2023-01-10    NaN  Electronics  South
# DRC_A      2023-01-11    NaN     Clothing   West
# Kenya_B    2023-01-12  377.0         Food  North
# Tanzania_A 2023-01-13   52.0         Food  South
# DRC_C      2023-01-14  371.0         Food   East
# Kenya_A    2023-01-15  356.0     Clothing   West
# Kenya_A    2023-01-16  183.0         Food   West
# Kenya_C    2023-01-17  474.0  Electronics   East
# Uganda_A   2023-01-18  477.0  Electronics  South
# ...

# %%
new_df = df.set_index(["Country", "Product"])
new_df.head()
# Out:
#                        Date  Sales     Category Region
# Country  Product
# DRC      A       2023-01-01  446.0         Food  North
# Tanzania C       2023-01-02   56.0  Electronics  South
# Uganda   C       2023-01-03   65.0     Clothing  South
# Kenya    B       2023-01-04  364.0     Clothing   West
#          C       2023-01-05  260.0  Electronics   West

# %%
new_df.index = new_df.index.to_flat_index()
new_df.head()
# Out:
#                     Date  Sales     Category Region
# (DRC, A)      2023-01-01  446.0         Food  North
# (Tanzania, C) 2023-01-02   56.0  Electronics  South
# (Uganda, C)   2023-01-03   65.0     Clothing  South
# (Kenya, B)    2023-01-04  364.0     Clothing   West
# (Kenya, C)    2023-01-05  260.0  Electronics   West

# %%
new_df = df.set_index(["Country", "Product"])
new_df.head()
# Out:
#                        Date  Sales     Category Region
# Country  Product
# DRC      A       2023-01-01  446.0         Food  North
# Tanzania C       2023-01-02   56.0  Electronics  South
# Uganda   C       2023-01-03   65.0     Clothing  South
# Kenya    B       2023-01-04  364.0     Clothing   West
#          C       2023-01-05  260.0  Electronics   West

# %%
Country_sales_sum = new_df.groupby(level='Country')['Sales'].sum()
Country_sales_sum
# Out:
# Country
# DRC         2345.0
# Kenya       3983.0
# Tanzania    4144.0
# Uganda      1312.0
# Name: Sales, dtype: float64

# %%
new_df.sort_index(level='Country')
# Out:
#                        Date  Sales     Category Region
# Country  Product
# DRC      A       2023-01-01  446.0         Food  North
#          A       2023-01-06    NaN  Electronics  South
#          A       2023-01-11    NaN     Clothing   West
#          A       2023-02-08  233.0     Clothing  North
#          A       2023-02-14  124.0  Electronics  North
#          A       2023-02-18   65.0  Electronics  South
#          B       2023-02-03  135.0     Clothing  South
#          B       2023-02-05  418.0     Clothing   East
#          C       2023-01-14  371.0         Food   East
#          C       2023-01-27   65.0  Electronics   West
#          C       2023-02-02  488.0         Food  North
# Kenya    A       2023-01-09    NaN  Electronics  North
#          A       2023-01-15  356.0     Clothing   West
#          A       2023-01-16  183.0         Food   West
#          A       2023-01-24  315.0  Electronics   East
#          A       2023-02-04  193.0  Electronics   West
# ...

# %%
new_df = df.set_index(["Country", "Product"])
new_df.head()
# Out:
#                        Date  Sales     Category Region
# Country  Product
# DRC      A       2023-01-01  446.0         Food  North
# Tanzania C       2023-01-02   56.0  Electronics  South
# Uganda   C       2023-01-03   65.0     Clothing  South
# Kenya    B       2023-01-04  364.0     Clothing   West
#          C       2023-01-05  260.0  Electronics   West

# %%
filtered_kenya = new_df.loc['Kenya']
filtered_kenya.head()
# Out:
#               Date  Sales     Category Region
# Product
# B       2023-01-04  364.0     Clothing   West
# C       2023-01-05  260.0  Electronics   West
# C       2023-01-07    NaN  Electronics   West
# C       2023-01-08    NaN         Food   East
# A       2023-01-09    NaN  Electronics  North

# %%
new_df.reset_index()
# Out:
#      Country Product       Date  Sales     Category Region
# 0        DRC       A 2023-01-01  446.0         Food  North
# 1   Tanzania       C 2023-01-02   56.0  Electronics  South
# 2     Uganda       C 2023-01-03   65.0     Clothing  South
# 3      Kenya       B 2023-01-04  364.0     Clothing   West
# 4      Kenya       C 2023-01-05  260.0  Electronics   West
# 5        DRC       A 2023-01-06    NaN  Electronics  South
# 6      Kenya       C 2023-01-07    NaN  Electronics   West
# 7      Kenya       C 2023-01-08    NaN         Food   East
# 8      Kenya       A 2023-01-09    NaN  Electronics  North
# 9     Uganda       C 2023-01-10    NaN  Electronics  South
# 10       DRC       A 2023-01-11    NaN     Clothing   West
# 11     Kenya       B 2023-01-12  377.0         Food  North
# 12  Tanzania       A 2023-01-13   52.0         Food  South
# 13       DRC       C 2023-01-14  371.0         Food   East
# 14     Kenya       A 2023-01-15  356.0     Clothing   West
# ...

# %%
df.head()
# Out:
#         Date   Country Product  Sales     Category Region
# 0 2023-01-01       DRC       A  446.0         Food  North
# 1 2023-01-02  Tanzania       C   56.0  Electronics  South
# 2 2023-01-03    Uganda       C   65.0     Clothing  South
# 3 2023-01-04     Kenya       B  364.0     Clothing   West
# 4 2023-01-05     Kenya       C  260.0  Electronics   West

# %%
pivot_table = df.pivot_table(index='Country',columns='Product', values='Sales', aggfunc='sum')
pivot_table
# Out:
# Product        A       B       C
# Country
# DRC        868.0   553.0   924.0
# Kenya     1117.0  1304.0  1562.0
# Tanzania   461.0  2478.0  1205.0
# Uganda     670.0   133.0   509.0

# %%
pivot_table2 = df.pivot_table(
index=['Country', 'Category'],#multiple index columns
columns=['Product'],#multiple columns for products
values=['Sales'],#values to aggregate
aggfunc=['sum', 'mean'])#\multiple aggregations for columns
pivot_table2
# Out:
#                         sum                       mean
#                       Sales                      Sales
# Product                   A       B      C           A           B           C
# Country  Category
# DRC      Clothing     233.0   553.0    NaN  233.000000  276.500000         NaN
#          Electronics  189.0     NaN   65.0   94.500000         NaN   65.000000
#          Food         446.0     NaN  859.0  446.000000         NaN  429.500000
# Kenya    Clothing     356.0   364.0  456.0  356.000000  364.000000  228.000000
#          Electronics  578.0     NaN  972.0  192.666667         NaN  324.000000
#          Food         183.0   940.0  134.0  183.000000  313.333333  134.000000
# Tanzania Clothing       NaN   644.0  310.0         NaN  322.000000  310.000000
#          Electronics  409.0  1132.0  895.0  204.500000  377.333333  298.333333
#          Food          52.0   702.0    NaN   52.000000  234.000000         NaN
# ...

# %%
pivot_table.sort_values(by = 'A', ascending=False)
# Out:
# Product        A       B       C
# Country
# Kenya     1117.0  1304.0  1562.0
# DRC        868.0   553.0   924.0
# Uganda     670.0   133.0   509.0
# Tanzania   461.0  2478.0  1205.0

# %%
additional_data=pd.DataFrame({
'Country':['Kenya', 'Uganda', 'Tanzania'],
    'GDP':[21,1.7,4.2]
})
additional_data
# Out:
#     Country   GDP
# 0     Kenya  21.0
# 1    Uganda   1.7
# 2  Tanzania   4.2

# %%
#Merging the original dataset with additional data based on country

# %%
merged_df = pd.merge(df, additional_data, on='Country', how='left')
merged_df.head()
# Out:
#         Date   Country Product  Sales     Category Region   GDP
# 0 2023-01-01       DRC       A  446.0         Food  North   NaN
# 1 2023-01-02  Tanzania       C   56.0  Electronics  South   4.2
# 2 2023-01-03    Uganda       C   65.0     Clothing  South   1.7
# 3 2023-01-04     Kenya       B  364.0     Clothing   West  21.0
# 4 2023-01-05     Kenya       C  260.0  Electronics   West  21.0

# %%
df.head()
# Out:
#         Date   Country Product  Sales     Category Region
# 0 2023-01-01       DRC       A  446.0         Food  North
# 1 2023-01-02  Tanzania       C   56.0  Electronics  South
# 2 2023-01-03    Uganda       C   65.0     Clothing  South
# 3 2023-01-04     Kenya       B  364.0     Clothing   West
# 4 2023-01-05     Kenya       C  260.0  Electronics   West

# %%
merged_df = pd.merge(df, additional_data, on='Country', how='right')
merged_df.head()
# Out:
#         Date Country Product  Sales     Category Region   GDP
# 0 2023-01-04   Kenya       B  364.0     Clothing   West  21.0
# 1 2023-01-05   Kenya       C  260.0  Electronics   West  21.0
# 2 2023-01-07   Kenya       C    NaN  Electronics   West  21.0
# 3 2023-01-08   Kenya       C    NaN         Food   East  21.0
# 4 2023-01-09   Kenya       A    NaN  Electronics  North  21.0

# %%
df.set_index('Country').join(additional_data.set_index('Country'))
# Out:
#                Date Product  Sales     Category Region   GDP
# Country
# DRC      2023-01-01       A  446.0         Food  North   NaN
# Tanzania 2023-01-02       C   56.0  Electronics  South   4.2
# Uganda   2023-01-03       C   65.0     Clothing  South   1.7
# Kenya    2023-01-04       B  364.0     Clothing   West  21.0
# Kenya    2023-01-05       C  260.0  Electronics   West  21.0
# DRC      2023-01-06       A    NaN  Electronics  South   NaN
# Kenya    2023-01-07       C    NaN  Electronics   West  21.0
# Kenya    2023-01-08       C    NaN         Food   East  21.0
# Kenya    2023-01-09       A    NaN  Electronics  North  21.0
# Uganda   2023-01-10       C    NaN  Electronics  South   1.7
# DRC      2023-01-11       A    NaN     Clothing   West   NaN
# Kenya    2023-01-12       B  377.0         Food  North  21.0
# Tanzania 2023-01-13       A   52.0         Food  South   4.2
# DRC      2023-01-14       C  371.0         Food   East   NaN
# ...

# %%
df.set_index('Country').join(additional_data.set_index('GDP'))
# Out:
#                Date Product  Sales     Category Region Country
# Country
# DRC      2023-01-01       A  446.0         Food  North     NaN
# Tanzania 2023-01-02       C   56.0  Electronics  South     NaN
# Uganda   2023-01-03       C   65.0     Clothing  South     NaN
# Kenya    2023-01-04       B  364.0     Clothing   West     NaN
# Kenya    2023-01-05       C  260.0  Electronics   West     NaN
# DRC      2023-01-06       A    NaN  Electronics  South     NaN
# Kenya    2023-01-07       C    NaN  Electronics   West     NaN
# Kenya    2023-01-08       C    NaN         Food   East     NaN
# Kenya    2023-01-09       A    NaN  Electronics  North     NaN
# Uganda   2023-01-10       C    NaN  Electronics  South     NaN
# DRC      2023-01-11       A    NaN     Clothing   West     NaN
# Kenya    2023-01-12       B  377.0         Food  North     NaN
# Tanzania 2023-01-13       A   52.0         Food  South     NaN
# DRC      2023-01-14       C  371.0         Food   East     NaN
# ...
